# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f0a9732fea2e7af2e8447166e815faa4

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | haysville
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | hongjiang
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | los llanos de aridane
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | flin flon
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | ust-ordynskiy
# Processing Record 19 of Set 1 | sinnamary
# Processing Record 20 of Set 1 | lumsden
# Processing Record 21 of Set 1 | makakilo city
# Processing Record 22 of Set 1 | bundibugyo
# Processing Record 23 of Set 1 | poum
# Processing Record 24 of Set 1 | lethem
# Processing Record 25 of Set 1 | okakarara
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | douglas
# Processing Record 28 of Set 1 | riachao
# Processing Record 29 of Set 1 | jibuti
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 1 | russell
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | panguipulli
# Processing Record 36 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 1 | norman wells
# Processing Record 38 of Set 1 | belaya gora
# Processing Record 39 of Set 1 | thana
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | hovd
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | ponta delgada
# Processing Record 44 of Set 1 | harper
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | houma
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | buala
# Processing Record 2 of Set 2 | fortuna
# Processing Record 3 of Set 2 | moratuwa
# Processing Record 4 of Set 2 | augusto correa
# Processing Record 5 of Set 2 | ngunguru
# Processing Record 6 of Set 2 | iquitos
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | tommot
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | bandarbeyla
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | lusambo
# Processing Record 16 of Set 2 | letpadan
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | the valley
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | port hardy
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | kudahuvadhoo
# Processing Record 26 of Set 2 | beroroha
# Processing Record 27 of Set 2 | iberia
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | aloleng
# Processing Record 30 of Set 2 | kirakira
# Processing Record 31 of Set 2 | zapolyarnyy
# Processing Record 32 of Set 2 | xiamen
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | mumbwa
# Processing Record 36 of Set 2 | malm
# Processing Record 37 of Set 2 | rocha
# Processing Record 38 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 2 | upata
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | kuytun
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | maloy
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | natal
# Processing Record 46 of Set 2 | acapulco
# Processing Record 47 of Set 2 | kendari
# Processing Record 48 of Set 2 | harlingen
# Processing Record 49 of Set 2 | japura
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | port-gentil
# Processing Record 3 of Set 3 | kihei
# Processing Record 4 of Set 3 | taylors
# Processing Record 5 of Set 3 | muros
# Processing Record 6 of Set 3 | aasiaat
# Processing Record 7 of Set 3 | chino
# Processing Record 8 of Set 3 | nome
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | asau
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | linxia
# Processing Record 14 of Set 3 | saint-augustin
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | guarapari
# Processing Record 18 of Set 3 | coahuayana
# Processing Record 19 of Set 3 | dunedin
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | puerto ayora
# Processing Record 22 of Set 3 | paamiut
# Processing Record 23 of Set 3 | glace bay
# Processing Record 24 of Set 3 | saint george
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | erzurum
# Processing Record 27 of Set 3 | alyangula
# Processing Record 28 of Set 3 | andra
# Processing Record 29 of Set 3 | saint anthony
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 3 | vitim
# Processing Record 33 of Set 3 | teguldet
# Processing Record 34 of Set 3 | gat
# Processing Record 35 of Set 3 | namibe
# Processing Record 36 of Set 3 | villa union
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | ginir
# Processing Record 40 of Set 3 | zhezkazgan
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | phumi samraong
# City not found. Skipping...
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | isangel
# Processing Record 45 of Set 3 | grindavik
# Processing Record 46 of Set 3 | lagoa
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | gasa
# Processing Record 5 of Set 4 | bonavista
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | batemans bay
# Processing Record 8 of Set 4 | san jose
# Processing Record 9 of Set 4 | hilo
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | vao
# Processing Record 13 of Set 4 | eureka
# Processing Record 14 of Set 4 | vaitape
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | chabua
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | saint-georges
# Processing Record 19 of Set 4 | la baule-escoublac
# Processing Record 20 of Set 4 | mae sot
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | yellowknife
# Processing Record 23 of Set 4 | neuquen
# Processing Record 24 of Set 4 | haademeeste
# City not found. Skipping...
# Processing Record 25 of Set 4 | hirara
# Processing Record 26 of Set 4 | rincon
# Processing Record 27 of Set 4 | komsomolskiy
# Processing Record 28 of Set 4 | cabo san lucas
# Processing Record 29 of Set 4 | hambantota
# Processing Record 30 of Set 4 | estelle
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | manado
# Processing Record 33 of Set 4 | nha trang
# Processing Record 34 of Set 4 | santa cruz
# Processing Record 35 of Set 4 | portland
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | havre-saint-pierre
# Processing Record 38 of Set 4 | sibu
# Processing Record 39 of Set 4 | shingu
# Processing Record 40 of Set 4 | el alto
# Processing Record 41 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 42 of Set 4 | palmerston
# Processing Record 43 of Set 4 | bata
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | berd
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | ruidoso
# Processing Record 49 of Set 4 | rudnaya pristan
# Processing Record 50 of Set 4 | iqaluit
# Processing Record 1 of Set 5 | acarau
# Processing Record 2 of Set 5 | noumea
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | nusaybin
# Processing Record 5 of Set 5 | kikwit
# Processing Record 6 of Set 5 | vrangel
# Processing Record 7 of Set 5 | caravelas
# Processing Record 8 of Set 5 | flinders
# Processing Record 9 of Set 5 | puerto escondido
# Processing Record 10 of Set 5 | we
# City not found. Skipping...
# Processing Record 11 of Set 5 | east london
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | cervo
# Processing Record 14 of Set 5 | lavrentiya
# Processing Record 15 of Set 5 | victoria
# Processing Record 16 of Set 5 | nowy sacz
# Processing Record 17 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 5 | santa rosa
# Processing Record 19 of Set 5 | ocos
# Processing Record 20 of Set 5 | laiagam
# City not found. Skipping...
# Processing Record 21 of Set 5 | beloha
# Processing Record 22 of Set 5 | pangody
# Processing Record 23 of Set 5 | umm lajj
# Processing Record 24 of Set 5 | olsztyn
# Processing Record 25 of Set 5 | werda
# Processing Record 26 of Set 5 | nizwa
# Processing Record 27 of Set 5 | arawa
# Processing Record 28 of Set 5 | oranjemund
# Processing Record 29 of Set 5 | yurginskoye
# Processing Record 30 of Set 5 | ocala
# Processing Record 31 of Set 5 | great falls
# Processing Record 32 of Set 5 | chokurdakh
# Processing Record 33 of Set 5 | rantauprapat
# Processing Record 34 of Set 5 | nanakuli
# Processing Record 35 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 5 | bira
# Processing Record 37 of Set 5 | taoudenni
# Processing Record 38 of Set 5 | ozu
# Processing Record 39 of Set 5 | olafsvik
# Processing Record 40 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 5 | meadow lake
# Processing Record 42 of Set 5 | tadine
# Processing Record 43 of Set 5 | gorshechnoye
# Processing Record 44 of Set 5 | canala
# Processing Record 45 of Set 5 | emerald
# Processing Record 46 of Set 5 | baghdad
# Processing Record 47 of Set 5 | kenora
# Processing Record 48 of Set 5 | storforshei
# Processing Record 49 of Set 5 | cherskiy
# Processing Record 50 of Set 5 | lata
# Processing Record 1 of Set 6 | pahrump
# Processing Record 2 of Set 6 | touros
# Processing Record 3 of Set 6 | lucea
# Processing Record 4 of Set 6 | sorrento
# Processing Record 5 of Set 6 | saint-jean-de-maurienne
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | mujiayingzi
# Processing Record 8 of Set 6 | banepa
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | isiro
# Processing Record 11 of Set 6 | urumqi
# Processing Record 12 of Set 6 | rio de jesus
# Processing Record 13 of Set 6 | khatanga
# Processing Record 14 of Set 6 | trenggalek
# Processing Record 15 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 6 | wageningen
# Processing Record 17 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 6 | domna
# Processing Record 19 of Set 6 | maniitsoq
# Processing Record 20 of Set 6 | rawson
# Processing Record 21 of Set 6 | matara
# Processing Record 22 of Set 6 | teya
# Processing Record 23 of Set 6 | saint paul
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | tabas
# Processing Record 28 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | egvekinot
# Processing Record 31 of Set 6 | lagos
# Processing Record 32 of Set 6 | leningradskiy
# Processing Record 33 of Set 6 | teruel
# Processing Record 34 of Set 6 | ganzhou
# Processing Record 35 of Set 6 | nalut
# Processing Record 36 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 6 | sechura
# Processing Record 38 of Set 6 | itarema
# Processing Record 39 of Set 6 | cambridge
# Processing Record 40 of Set 6 | namatanai
# Processing Record 41 of Set 6 | weyburn
# Processing Record 42 of Set 6 | narsaq
# Processing Record 43 of Set 6 | sandwick
# Processing Record 44 of Set 6 | cap-aux-meules
# Processing Record 45 of Set 6 | sulangan
# Processing Record 46 of Set 6 | hailey
# Processing Record 47 of Set 6 | constitucion
# Processing Record 48 of Set 6 | aracaju
# Processing Record 49 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 6 | katsuura
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | gweta
# Processing Record 3 of Set 7 | tuatapere
# Processing Record 4 of Set 7 | karangasem
# Processing Record 5 of Set 7 | necochea
# Processing Record 6 of Set 7 | fredericton
# Processing Record 7 of Set 7 | bojnurd
# Processing Record 8 of Set 7 | miyako
# Processing Record 9 of Set 7 | truckee
# Processing Record 10 of Set 7 | chapais
# Processing Record 11 of Set 7 | nishihara
# Processing Record 12 of Set 7 | hithadhoo
# Processing Record 13 of Set 7 | port keats
# Processing Record 14 of Set 7 | dicabisagan
# Processing Record 15 of Set 7 | mersing
# Processing Record 16 of Set 7 | opovo
# Processing Record 17 of Set 7 | pistsovo
# Processing Record 18 of Set 7 | laguna
# Processing Record 19 of Set 7 | qaqortoq
# Processing Record 20 of Set 7 | esperance
# Processing Record 21 of Set 7 | sao filipe
# Processing Record 22 of Set 7 | bengkulu
# Processing Record 23 of Set 7 | swiecie
# Processing Record 24 of Set 7 | ossora
# Processing Record 25 of Set 7 | castro
# Processing Record 26 of Set 7 | siva
# Processing Record 27 of Set 7 | fez
# Processing Record 28 of Set 7 | vila velha
# Processing Record 29 of Set 7 | nova olimpia
# Processing Record 30 of Set 7 | plaeng yao
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | katherine
# Processing Record 33 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 7 | plouzane
# Processing Record 36 of Set 7 | raga
# Processing Record 37 of Set 7 | forestville
# Processing Record 38 of Set 7 | bulgan
# Processing Record 39 of Set 7 | popondetta
# Processing Record 40 of Set 7 | roma
# Processing Record 41 of Set 7 | tumalaytay
# Processing Record 42 of Set 7 | tougan
# Processing Record 43 of Set 7 | alto araguaia
# Processing Record 44 of Set 7 | gigmoto
# Processing Record 45 of Set 7 | hami
# Processing Record 46 of Set 7 | ferme-neuve
# Processing Record 47 of Set 7 | taltal
# Processing Record 48 of Set 7 | iwaki
# Processing Record 49 of Set 7 | codrington
# Processing Record 50 of Set 7 | kropotkin
# Processing Record 1 of Set 8 | lagunas
# Processing Record 2 of Set 8 | atar
# Processing Record 3 of Set 8 | aden
# Processing Record 4 of Set 8 | ponorogo
# Processing Record 5 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 8 | warmbad
# Processing Record 7 of Set 8 | marsa matruh
# Processing Record 8 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 9 of Set 8 | ceres
# Processing Record 10 of Set 8 | ugoofaaru
# Processing Record 11 of Set 8 | jiwani
# Processing Record 12 of Set 8 | trogir
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | shihezi
# Processing Record 15 of Set 8 | along
# Processing Record 16 of Set 8 | khandagayty
# Processing Record 17 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 8 | singaraja
# Processing Record 19 of Set 8 | torbay
# Processing Record 20 of Set 8 | kawalu
# Processing Record 21 of Set 8 | naze
# Processing Record 22 of Set 8 | pacific grove
# Processing Record 23 of Set 8 | talara
# Processing Record 24 of Set 8 | azuga
# Processing Record 25 of Set 8 | bongouanou
# Processing Record 26 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 8 | muisne
# Processing Record 28 of Set 8 | vila franca do campo
# Processing Record 29 of Set 8 | la plata
# Processing Record 30 of Set 8 | aranos
# Processing Record 31 of Set 8 | sur
# Processing Record 32 of Set 8 | quatre cocos
# Processing Record 33 of Set 8 | maltahohe
# Processing Record 34 of Set 8 | atoyac
# Processing Record 35 of Set 8 | beringovskiy
# Processing Record 36 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 37 of Set 8 | fairbanks
# Processing Record 38 of Set 8 | sorland
# Processing Record 39 of Set 8 | karratha
# Processing Record 40 of Set 8 | chaochou
# City not found. Skipping...
# Processing Record 41 of Set 8 | nowa sol
# Processing Record 42 of Set 8 | zhuhai
# Processing Record 43 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 8 | paita
# Processing Record 45 of Set 8 | garowe
# Processing Record 46 of Set 8 | anadyr
# Processing Record 47 of Set 8 | nelson bay
# Processing Record 48 of Set 8 | phalombe
# Processing Record 49 of Set 8 | kupang
# Processing Record 50 of Set 8 | tigil
# Processing Record 1 of Set 9 | gravelbourg
# Processing Record 2 of Set 9 | alice springs
# Processing Record 3 of Set 9 | hualmay
# Processing Record 4 of Set 9 | nador
# Processing Record 5 of Set 9 | bathsheba
# Processing Record 6 of Set 9 | puerto quijarro
# Processing Record 7 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 9 | pospelikha
# Processing Record 9 of Set 9 | kyabram
# Processing Record 10 of Set 9 | malanje
# Processing Record 11 of Set 9 | miri
# Processing Record 12 of Set 9 | kapuskasing
# Processing Record 13 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 9 | richards bay
# Processing Record 15 of Set 9 | port macquarie
# Processing Record 16 of Set 9 | verkhnyaya khava
# Processing Record 17 of Set 9 | ovalle
# Processing Record 18 of Set 9 | oussouye
# Processing Record 19 of Set 9 | moose factory
# Processing Record 20 of Set 9 | tonota
# Processing Record 21 of Set 9 | avera
# Processing Record 22 of Set 9 | matagami
# Processing Record 23 of Set 9 | bauchi
# Processing Record 24 of Set 9 | parker
# Processing Record 25 of Set 9 | lorengau
# Processing Record 26 of Set 9 | kachiry
# Processing Record 27 of Set 9 | pryozerne
# Processing Record 28 of Set 9 | schwedt
# Processing Record 29 of Set 9 | terre haute
# Processing Record 30 of Set 9 | ca mau
# Processing Record 31 of Set 9 | verdalsora
# City not found. Skipping...
# Processing Record 32 of Set 9 | sabha
# Processing Record 33 of Set 9 | maraa
# Processing Record 34 of Set 9 | buriti dos lopes
# Processing Record 35 of Set 9 | klobuck
# Processing Record 36 of Set 9 | torbat-e jam
# Processing Record 37 of Set 9 | yagodnoye
# Processing Record 38 of Set 9 | sabang
# Processing Record 39 of Set 9 | brae
# Processing Record 40 of Set 9 | ayorou
# Processing Record 41 of Set 9 | abnub
# Processing Record 42 of Set 9 | taitung
# Processing Record 43 of Set 9 | jinxiang
# Processing Record 44 of Set 9 | washington
# Processing Record 45 of Set 9 | yeppoon
# Processing Record 46 of Set 9 | labuhan
# Processing Record 47 of Set 9 | a
# City not found. Skipping...
# Processing Record 48 of Set 9 | kedrovyy
# Processing Record 49 of Set 9 | ayan
# Processing Record 50 of Set 9 | san cristobal
# Processing Record 1 of Set 10 | agadez
# Processing Record 2 of Set 10 | mareeba
# Processing Record 3 of Set 10 | sembe
# Processing Record 4 of Set 10 | salinopolis
# Processing Record 5 of Set 10 | maputo
# Processing Record 6 of Set 10 | mayumba
# Processing Record 7 of Set 10 | kantilo
# Processing Record 8 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 10 | santander jimenez
# Processing Record 10 of Set 10 | shakawe
# Processing Record 11 of Set 10 | trairi
# Processing Record 12 of Set 10 | havoysund
# Processing Record 13 of Set 10 | talnakh
# Processing Record 14 of Set 10 | balaipungut
# Processing Record 15 of Set 10 | banda aceh
# Processing Record 16 of Set 10 | oliveira dos brejinhos
# Processing Record 17 of Set 10 | denpasar
# Processing Record 18 of Set 10 | aklavik
# Processing Record 19 of Set 10 | manicaragua
# Processing Record 20 of Set 10 | tocantinopolis
# City not found. Skipping...
# Processing Record 21 of Set 10 | bestobe
# Processing Record 22 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 10 | bamnet narong
# Processing Record 24 of Set 10 | bonthe
# Processing Record 25 of Set 10 | conceicao do araguaia
# Processing Record 26 of Set 10 | gazli
# Processing Record 27 of Set 10 | san juan bautista
# Processing Record 28 of Set 10 | najran
# Processing Record 29 of Set 10 | kattivakkam
# Processing Record 30 of Set 10 | mount isa
# Processing Record 31 of Set 10 | namie
# Processing Record 32 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 33 of Set 10 | toowoomba
# Processing Record 34 of Set 10 | sinop
# Processing Record 35 of Set 10 | grand gaube
# Processing Record 36 of Set 10 | san bartolome
# Processing Record 37 of Set 10 | te anau
# Processing Record 38 of Set 10 | jeremie
# Processing Record 39 of Set 10 | ushtobe
# Processing Record 40 of Set 10 | itoman
# Processing Record 41 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 10 | toktogul
# Processing Record 43 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 44 of Set 10 | ibra
# Processing Record 45 of Set 10 | vestmannaeyjar
# Processing Record 46 of Set 10 | santa vitoria do palmar
# Processing Record 47 of Set 10 | vardo
# Processing Record 48 of Set 10 | salvacion
# Processing Record 49 of Set 10 | bowen
# Processing Record 50 of Set 10 | marsh harbour
# Processing Record 1 of Set 11 | patitirion
# Processing Record 2 of Set 11 | tikhvin
# Processing Record 3 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 11 | bay city
# Processing Record 5 of Set 11 | devadanapatti
# City not found. Skipping...
# Processing Record 6 of Set 11 | kyshtovka
# Processing Record 7 of Set 11 | bangassou
# Processing Record 8 of Set 11 | pelym
# Processing Record 9 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 10 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 11 | oleksandrivka
# Processing Record 12 of Set 11 | cowra
# Processing Record 13 of Set 11 | vanimo
# Processing Record 14 of Set 11 | roebourne
# Processing Record 15 of Set 11 | road town
# Processing Record 16 of Set 11 | golub-dobrzyn
# Processing Record 17 of Set 11 | meulaboh
# Processing Record 18 of Set 11 | collie
# Processing Record 19 of Set 11 | mattru
# Processing Record 20 of Set 11 | emba
# Processing Record 21 of Set 11 | suluq
# Processing Record 22 of Set 11 | dukat
# Processing Record 23 of Set 11 | ambilobe
# Processing Record 24 of Set 11 | kazlu ruda
# Processing Record 25 of Set 11 | dzaoudzi
# Processing Record 26 of Set 11 | bilibino
# Processing Record 27 of Set 11 | hastings
# Processing Record 28 of Set 11 | asfi
# Processing Record 29 of Set 11 | misratah
# Processing Record 30 of Set 11 | dhidhdhoo
# Processing Record 31 of Set 11 | shcholkine
# City not found. Skipping...
# Processing Record 32 of Set 11 | florence
# Processing Record 33 of Set 11 | bahia honda
# Processing Record 34 of Set 11 | chengde
# Processing Record 35 of Set 11 | stornoway
# Processing Record 36 of Set 11 | neiafu
# Processing Record 37 of Set 11 | ambagarh chauki
# Processing Record 38 of Set 11 | san ignacio
# Processing Record 39 of Set 11 | fomboni
# Processing Record 40 of Set 11 | ola
# Processing Record 41 of Set 11 | mitsamiouli
# Processing Record 42 of Set 11 | waunakee
# Processing Record 43 of Set 11 | the pas
# Processing Record 44 of Set 11 | san jose de rio tinto
# Processing Record 45 of Set 11 | metro
# Processing Record 46 of Set 11 | kavaratti
# Processing Record 47 of Set 11 | kamaishi
# Processing Record 48 of Set 11 | umaria
# Processing Record 49 of Set 11 | pipri
# Processing Record 50 of Set 11 | petawawa
# Processing Record 1 of Set 12 | tezu
# Processing Record 2 of Set 12 | husavik
# Processing Record 3 of Set 12 | jalu
# Processing Record 4 of Set 12 | tuy hoa
# Processing Record 5 of Set 12 | yar-sale
# Processing Record 6 of Set 12 | hamilton
# Processing Record 7 of Set 12 | hvolsvollur
# Processing Record 8 of Set 12 | wellington
# Processing Record 9 of Set 12 | huilong
# Processing Record 10 of Set 12 | knysna
# Processing Record 11 of Set 12 | riyadh
# Processing Record 12 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 12 | sao desiderio
# Processing Record 14 of Set 12 | kisaran
# Processing Record 15 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 16 of Set 12 | maningrida
# Processing Record 17 of Set 12 | padang
# Processing Record 18 of Set 12 | san vicente
# Processing Record 19 of Set 12 | klaksvik
# Processing Record 20 of Set 12 | hun
# Processing Record 21 of Set 12 | wuwei
# Processing Record 22 of Set 12 | srednekolymsk
# Processing Record 23 of Set 12 | diamantino
# Processing Record 24 of Set 12 | severnoye
# Processing Record 25 of Set 12 | mulchen
# Processing Record 26 of Set 12 | liaozhong
# Processing Record 27 of Set 12 | mongo
# Processing Record 28 of Set 12 | samfya
# Processing Record 29 of Set 12 | sangar
# Processing Record 30 of Set 12 | biak
# Processing Record 31 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 32 of Set 12 | antalaha
# Processing Record 33 of Set 12 | fort walton beach
# Processing Record 34 of Set 12 | guanare
# Processing Record 35 of Set 12 | abreus
# Processing Record 36 of Set 12 | mayo
# Processing Record 37 of Set 12 | tombouctou
# Processing Record 38 of Set 12 | hay river
# Processing Record 39 of Set 12 | san isidro
# Processing Record 40 of Set 12 | pontes e lacerda
# Processing Record 41 of Set 12 | stephenville
# Processing Record 42 of Set 12 | barcelos
# Processing Record 43 of Set 12 | warrensburg
# Processing Record 44 of Set 12 | marsaxlokk
# Processing Record 45 of Set 12 | businga
# Processing Record 46 of Set 12 | mirnyy
# Processing Record 47 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 48 of Set 12 | baykit
# Processing Record 49 of Set 12 | lugovskiy
# City not found. Skipping...
# Processing Record 50 of Set 12 | broome
# Processing Record 1 of Set 13 | whitianga
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | salalah
# Processing Record 4 of Set 13 | petukhovo
# Processing Record 5 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 13 | brunswick
# Processing Record 7 of Set 13 | tessalit
# Processing Record 8 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 13 | planaltina
# Processing Record 10 of Set 13 | nambucca heads
# Processing Record 11 of Set 13 | jackson
# Processing Record 12 of Set 13 | cloquet
# Processing Record 13 of Set 13 | grants
# Processing Record 14 of Set 13 | yulara
# Processing Record 15 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 13 | tual
# Processing Record 17 of Set 13 | bilma
# Processing Record 18 of Set 13 | bom jesus
# Processing Record 19 of Set 13 | dodge city
# Processing Record 20 of Set 13 | waingapu
# Processing Record 21 of Set 13 | auki
# Processing Record 22 of Set 13 | jember
# Processing Record 23 of Set 13 | kaeo
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | mustasaari
# Processing Record 26 of Set 13 | albania
# Processing Record 27 of Set 13 | goderich
# Processing Record 28 of Set 13 | batagay
# Processing Record 29 of Set 13 | shache
# Processing Record 30 of Set 13 | grafton
# Processing Record 31 of Set 13 | san patricio
# Processing Record 32 of Set 13 | chipinge
# Processing Record 33 of Set 13 | xining
# Processing Record 34 of Set 13 | sladkovo
# Processing Record 35 of Set 13 | alta floresta
# Processing Record 36 of Set 13 | buin
# Processing Record 37 of Set 13 | visby
# Processing Record 38 of Set 13 | kulhudhuffushi
# Processing Record 39 of Set 13 | tomatlan
# Processing Record 40 of Set 13 | bow island
# Processing Record 41 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | orichi
# Processing Record 43 of Set 13 | mecca
# Processing Record 44 of Set 13 | kralendijk
# Processing Record 45 of Set 13 | pangani
# Processing Record 46 of Set 13 | ukiah
# Processing Record 47 of Set 13 | hosanagara
# Processing Record 48 of Set 13 | anchorage
# Processing Record 49 of Set 13 | mana
# Processing Record 50 of Set 13 | sola
# Processing Record 1 of Set 14 | wa
# City not found. Skipping...
# Processing Record 2 of Set 14 | novosheshminsk
# Processing Record 3 of Set 14 | kimbe
# Processing Record 4 of Set 14 | palauig
# Processing Record 5 of Set 14 | tautira
# Processing Record 6 of Set 14 | hauterive
# Processing Record 7 of Set 14 | sistranda
# Processing Record 8 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 9 of Set 14 | porto novo
# Processing Record 10 of Set 14 | carballo
# Processing Record 11 of Set 14 | simbahan
# Processing Record 12 of Set 14 | silca
# Processing Record 13 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 14 | kampene
# Processing Record 15 of Set 14 | bosaso
# Processing Record 16 of Set 14 | kostomuksha
# Processing Record 17 of Set 14 | marawi
# Processing Record 18 of Set 14 | vostok
# Processing Record 19 of Set 14 | martinsburg
# Processing Record 20 of Set 14 | bintulu
# Processing Record 21 of Set 14 | okhotsk
# Processing Record 22 of Set 14 | olinda
# Processing Record 23 of Set 14 | itauna
# Processing Record 24 of Set 14 | kashkhatau
# Processing Record 25 of Set 14 | vila
# Processing Record 26 of Set 14 | chardara
# Processing Record 27 of Set 14 | kostek
# Processing Record 28 of Set 14 | mahbubnagar
# Processing Record 29 of Set 14 | la ronge
# Processing Record 30 of Set 14 | sao felix do xingu
# Processing Record 31 of Set 14 | socorro
# Processing Record 32 of Set 14 | takoradi
# Processing Record 33 of Set 14 | berdigestyakh
# Processing Record 34 of Set 14 | walvis bay
# Processing Record 35 of Set 14 | rodrigues alves
# Processing Record 36 of Set 14 | bafata
# Processing Record 37 of Set 14 | zhumadian
# Processing Record 38 of Set 14 | rawah
# Processing Record 39 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 40 of Set 14 | encheng
# Processing Record 41 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 14 | la asuncion
# Processing Record 43 of Set 14 | henties bay
# Processing Record 44 of Set 14 | san andres
# Processing Record 45 of Set 14 | ambon
# Processing Record 46 of Set 14 | khilchipur
# Processing Record 47 of Set 14 | saint-pierre
# Processing Record 48 of Set 14 | davila
# Processing Record 49 of Set 14 | tateyama
# Processing Record 50 of Set 14 | poronaysk
# Processing Record 1 of Set 15 | gunnedah
# Processing Record 2 of Set 15 | surt
# Processing Record 3 of Set 15 | green river
# Processing Record 4 of Set 15 | pitimbu
# Processing Record 5 of Set 15 | newport
# Processing Record 6 of Set 15 | buraydah
# Processing Record 7 of Set 15 | port moresby
# Processing Record 8 of Set 15 | northam
# Processing Record 9 of Set 15 | sarai
# Processing Record 10 of Set 15 | brigantine
# Processing Record 11 of Set 15 | sakakah
# Processing Record 12 of Set 15 | nagato
# Processing Record 13 of Set 15 | chulym
# Processing Record 14 of Set 15 | piacabucu
# Processing Record 15 of Set 15 | skjervoy
# Processing Record 16 of Set 15 | markova
# Processing Record 17 of Set 15 | katha
# City not found. Skipping...
# Processing Record 18 of Set 15 | iracoubo
# Processing Record 19 of Set 15 | usta muhammad
# Processing Record 20 of Set 15 | stepnogorsk
# Processing Record 21 of Set 15 | baracoa
# Processing Record 22 of Set 15 | lakes entrance
# Processing Record 23 of Set 15 | geraldton
# Processing Record 24 of Set 15 | autazes
# Processing Record 25 of Set 15 | inta
# Processing Record 26 of Set 15 | naushki
# Processing Record 27 of Set 15 | nasice
# Processing Record 28 of Set 15 | buluang
# Processing Record 29 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 15 | culebra
# Processing Record 31 of Set 15 | baijiantan
# Processing Record 32 of Set 15 | carbonia
# Processing Record 33 of Set 15 | zafra
# Processing Record 34 of Set 15 | hammerfest
# Processing Record 35 of Set 15 | bartica
# Processing Record 36 of Set 15 | arauco
# Processing Record 37 of Set 15 | vuktyl
# Processing Record 38 of Set 15 | rio grande
# Processing Record 39 of Set 15 | comodoro rivadavia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 673

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Punta Arenas -53.1500  -70.9167     46.51        71          75
# 1               Cidreira -30.1811  -50.2056     70.68        70          48
# 2               Souillac -20.5167   57.5167     82.78        83          75
# 3        Bambous Virieux -20.3428   57.7575     83.21        83          75
# 4            New Norfolk -42.7826  147.0587     65.91        46         100
# 5              Haysville  37.5645  -97.3523     46.72        51          40
# 6              Cape Town -33.9258   18.4232     67.37        82          75
# 7              Hongjiang  27.1100  109.9956     64.38        39          47
# 8                Ushuaia -54.8000  -68.3000     42.46        81          40
# 9  Los Llanos De Aridane  28.6585  -17.9182     56.95        84         100
#
#    Wind Speed Country Current Description
# 0       14.97      CL       broken clouds
# 1       14.05      BR    scattered clouds
# 2       13.80      MU          light rain
# 3       13.80      MU          light rain
# 4        7.00      AU     overcast clouds
# 5        8.05      US    scattered clouds
# 6       27.63      ZA       moderate rain
# 7        4.68      CN    scattered clouds
# 8        4.61      AR    scattered clouds
# 9       10.36      ES     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_order]

# Display sample data
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Punta Arenas      CL -53.1500  -70.9167     46.51        71
# 1               Cidreira      BR -30.1811  -50.2056     70.68        70
# 2               Souillac      MU -20.5167   57.5167     82.78        83
# 3        Bambous Virieux      MU -20.3428   57.7575     83.21        83
# 4            New Norfolk      AU -42.7826  147.0587     65.91        46
# 5              Haysville      US  37.5645  -97.3523     46.72        51
# 6              Cape Town      ZA -33.9258   18.4232     67.37        82
# 7              Hongjiang      CN  27.1100  109.9956     64.38        39
# 8                Ushuaia      AR -54.8000  -68.3000     42.46        81
# 9  Los Llanos De Aridane      ES  28.6585  -17.9182     56.95        84
#
#    Cloudiness  Wind Speed Current Description
# 0          75       14.97       broken clouds
# 1          48       14.05    scattered clouds
# 2          75       13.80          light rain
# 3          75       13.80          light rain
# 4         100        7.00     overcast clouds
# 5          40        8.05    scattered clouds
# 6          75       27.63       moderate rain
# 7          47        4.68    scattered clouds
# 8          40        4.61    scattered clouds
# 9         100       10.36     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 673 non-null    object
#  1   Country              673 non-null    object
#  2   Lat                  673 non-null    float64
#  3   Lng                  673 non-null    float64
#  4   Max Temp             673 non-null    float64
#  5   Humidity             673 non-null    int64
#  6   Cloudiness           673 non-null    int64
#  7   Wind Speed           673 non-null    float64
#  8   Current Description  673 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 47.4+ KB

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
